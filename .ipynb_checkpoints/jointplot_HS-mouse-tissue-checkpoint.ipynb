# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mouse_meta-data_tissue.csv")
df
# Out:
#           pair  temperature  time(h.)                     tissue  \
# 0   SRR8835898         42.4      0.00                     kidney
# 1   SRR8835908         42.4      0.00                     kidney
# 2   SRR8835910         42.4      0.00                     kidney
# 3   SRR8835917         42.4      0.00                     kidney
# 4   SRR8835894         42.4      0.00                     kidney
# ..         ...          ...       ...                        ...
# 75  SRR5306700         41.5      0.25  quadriceps femoris muscle
# 76  SRR5306703         41.5      0.25  quadriceps femoris muscle
# 77  SRR5306704         41.5      0.25  quadriceps femoris muscle
# 78  SRR5306707         41.5      0.25  quadriceps femoris muscle
# 79  SRR5306708         41.5      0.25  quadriceps femoris muscle
#
#              Instrument  SRA Study        data supplement      ikra
# 0   Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# 1   Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# 2   Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# 3   Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# 4   Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# ..                  ...        ...         ...        ...       ...
# 75  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# 76  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# 77  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# 78  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# 79  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
#
# [80 rows x 9 columns]

# %%
df1 = df.set_index('pair')
df1
# Out:
#             temperature  time(h.)                     tissue  \
# pair
# SRR8835898         42.4      0.00                     kidney
# SRR8835908         42.4      0.00                     kidney
# SRR8835910         42.4      0.00                     kidney
# SRR8835917         42.4      0.00                     kidney
# SRR8835894         42.4      0.00                     kidney
# ...                 ...       ...                        ...
# SRR5306700         41.5      0.25  quadriceps femoris muscle
# SRR5306703         41.5      0.25  quadriceps femoris muscle
# SRR5306704         41.5      0.25  quadriceps femoris muscle
# SRR5306707         41.5      0.25  quadriceps femoris muscle
# SRR5306708         41.5      0.25  quadriceps femoris muscle
#
#                      Instrument  SRA Study        data supplement      ikra
# pair
# SRR8835898  Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# SRR8835908  Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# SRR8835910  Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# SRR8835917  Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# SRR8835894  Illumina HiSeq 2000  SRP190135  mouse_A_SE    RNA-seq  complete
# ...                         ...        ...         ...        ...       ...
# SRR5306700  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# SRR5306703  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# SRR5306704  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# SRR5306707  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
# SRR5306708  Illumina HiSeq 2000  SRP100979  mouse_A_PE    RNA-seq  complete
#
# [80 rows x 8 columns]

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
# 色指定できる
g = sns.set_palette('ocean')
g = sns.jointplot(data=df, x='temperature', y='time(h.)', kind='hist', height=10, ratio=4, marginal_ticks=True)

g = plt.show()
