# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mouse_meta-data.csv")
df
# Out:
#            pair  temperature  time(h.)            cell-type  \
# 0    SRR2068908           39       1.0  Splenic B220+ cells
# 1    SRR2068909           39       1.0  Splenic B220+ cells
# 2    SRR2068912           39       1.0  Splenic B220+ cells
# 3    SRR2068913           39       1.0  Splenic B220+ cells
# 4    SRR8494667           42       0.5                 mESC
# ..          ...          ...       ...                  ...
# 79  SRR10363979           43       0.5    Cultured utricles
# 80   SRR5558715           44       2.0                  MEF
# 81   SRR5558716           44       2.0                  MEF
# 82    SRR649750           42       8.0             NIH/3T3
# 83    SRR649751           44       2.0             NIH/3T3
#
#                      Instrument  SRA Study        data supplement      ikra
# 0           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq  complete
# 1           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq  complete
# 2           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq  complete
# 3           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq  complete
# 4           Illumina HiSeq 2500  SRP182641  mouse_A_SE    RNA-seq  complete
# ..                          ...        ...         ...        ...       ...
# 79          Illumina HiSeq 1500  SRP227469  mouse_A_PE    RNA-seq  complete
# 80          Illumina HiSeq 2000  SRP107191  mouse_A_PE    RNA-seq  complete
# 81          Illumina HiSeq 2000  SRP107191  mouse_A_PE    RNA-seq  complete
# 82  Illumina Genome Analyzer II  SRP017942  mouse_A_PE    RNA-seq  complete
# 83  Illumina Genome Analyzer II  SRP017942  mouse_A_PE    RNA-seq  complete
#
# [84 rows x 9 columns]

# %%
df1 = df.set_index('pair')
df1
# Out:
#              temperature  time(h.)            cell-type  \
# pair
# SRR2068908            39       1.0  Splenic B220+ cells
# SRR2068909            39       1.0  Splenic B220+ cells
# SRR2068912            39       1.0  Splenic B220+ cells
# SRR2068913            39       1.0  Splenic B220+ cells
# SRR8494667            42       0.5                 mESC
# ...                  ...       ...                  ...
# SRR10363979           43       0.5    Cultured utricles
# SRR5558715            44       2.0                  MEF
# SRR5558716            44       2.0                  MEF
# SRR649750             42       8.0             NIH/3T3
# SRR649751             44       2.0             NIH/3T3
#
#                               Instrument  SRA Study        data supplement  \
# pair
# SRR2068908           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq
# SRR2068909           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq
# SRR2068912           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq
# SRR2068913           Illumina HiSeq 2000  SRP059622  mouse_A_SE    RNA-seq
# SRR8494667           Illumina HiSeq 2500  SRP182641  mouse_A_SE    RNA-seq
# ...                                  ...        ...         ...        ...
# SRR10363979          Illumina HiSeq 1500  SRP227469  mouse_A_PE    RNA-seq
# SRR5558715           Illumina HiSeq 2000  SRP107191  mouse_A_PE    RNA-seq
# SRR5558716           Illumina HiSeq 2000  SRP107191  mouse_A_PE    RNA-seq
# SRR649750    Illumina Genome Analyzer II  SRP017942  mouse_A_PE    RNA-seq
# SRR649751    Illumina Genome Analyzer II  SRP017942  mouse_A_PE    RNA-seq
#
#                  ikra
# pair
# SRR2068908   complete
# SRR2068909   complete
# SRR2068912   complete
# SRR2068913   complete
# SRR8494667   complete
# ...               ...
# SRR10363979  complete
# SRR5558715   complete
# SRR5558716   complete
# SRR649750    complete
# SRR649751    complete
#
# [84 rows x 8 columns]

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
# 色指定できる

g = sns.set(font_scale = 1.7)
g = sns.set_style("whitegrid")
g = sns.set_palette('YlGn_r')
g = sns.jointplot(data=df, x='temperature', y='time(h.)', kind='hist', height=10, ratio=4, marginal_ticks=True)

g = plt.show()
