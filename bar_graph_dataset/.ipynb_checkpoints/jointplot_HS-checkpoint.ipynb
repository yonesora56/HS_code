# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("human_meta-data2.csv")
df
# Out:
#             pair  temperature  time(min.)           Instrument  SRA Study  \
# 0     SRR8392699         44.0         120  Illumina HiSeq 2000  SRP175158
# 1     SRR8392700         44.0         120  Illumina HiSeq 2000  SRP175158
# 2     SRR8392703         44.0         120  Illumina HiSeq 2000  SRP175158
# 3     SRR8392704         44.0         120  Illumina HiSeq 2000  SRP175158
# 4    SRR10129832         43.0          60  Illumina HiSeq 2500  SRP221987
# ..           ...          ...         ...                  ...        ...
# 192   SRR5756347         44.0          60          NextSeq 500  SRP110507
# 193   SRR5756348         44.0         120          NextSeq 500  SRP110507
# 194   SRR5756349         44.0         120          NextSeq 500  SRP110507
# 195   SRR5756350         44.0         120          NextSeq 500  SRP110507
# 196   SRR5756351         44.0         120          NextSeq 500  SRP110507
#
#     organism        data   method      ikra
# ...

# %%
df1 = df.set_index('pair')
df1
# Out:
#              temperature  time(min.)           Instrument  SRA Study organism  \
# pair
# SRR8392699          44.0         120  Illumina HiSeq 2000  SRP175158    human
# SRR8392700          44.0         120  Illumina HiSeq 2000  SRP175158    human
# SRR8392703          44.0         120  Illumina HiSeq 2000  SRP175158    human
# SRR8392704          44.0         120  Illumina HiSeq 2000  SRP175158    human
# SRR10129832         43.0          60  Illumina HiSeq 2500  SRP221987    human
# ...                  ...         ...                  ...        ...      ...
# SRR5756347          44.0          60          NextSeq 500  SRP110507    human
# SRR5756348          44.0         120          NextSeq 500  SRP110507    human
# SRR5756349          44.0         120          NextSeq 500  SRP110507    human
# SRR5756350          44.0         120          NextSeq 500  SRP110507    human
# SRR5756351          44.0         120          NextSeq 500  SRP110507    human
#
# ...

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
# 色指定できる

g = sns.set(font_scale = 1.7)
g = sns.set_style("whitegrid")
g = sns.set_palette("Reds_r")
g = sns.jointplot(data=df, x='temperature', y='time(min.)', kind='hist', height=10, ratio=3, marginal_ticks=True)

g = plt.show()
