# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %matplotlib inline

plt.style.use('ggplot')

# %% [markdown]
# ### Using the HN-ratio table

# %%
df = pd.read_csv("../source/HN-ratio_mouse_All.csv", sep=",")
df.head()
# Out:
#         GeneName  SRR8835898  SRR8835908  SRR8835910  SRR8835917  SRR8835894  \
# 0  0610009B22Rik    0.888477    0.472901    0.585592    1.348745    0.704214
# 1  0610010F05Rik    1.301893    0.993249    1.090830    1.752709    1.050022
# 2  0610010K14Rik    1.633539    0.318482    1.338232    1.319906    0.724082
# 3  0610012G03Rik    1.250494    0.584869    0.656240    1.862847    0.672534
# 4  0610030E20Rik    1.021152    0.592594    0.937276    1.702173    0.969005
#
#    SRR8835928  SRR8835900  SRR8835904  SRR8835891  ...  SRR6262117  \
# 0    1.117431    0.731358    1.519465    1.117518  ...    4.652027
# 1    0.740508    0.682207    0.830300    1.085242  ...    3.486095
# 2    0.865305    1.264106    0.721409    0.853692  ...    3.138838
# 3    1.072469    0.937190    1.019688    1.160474  ...    2.659720
# 4    0.994161    0.797120    1.067343    1.102271  ...    3.718134
#
#    SRR6262104  SRR6262105  SRR6262108  SRR6262109  SRR13571065  SRR13571066  \
# ...

# %%
# set index 
df1=df.set_index('GeneName')
df1.head()
# Out:
#                SRR8835898  SRR8835908  SRR8835910  SRR8835917  SRR8835894  \
# GeneName
# 0610009B22Rik    0.888477    0.472901    0.585592    1.348745    0.704214
# 0610010F05Rik    1.301893    0.993249    1.090830    1.752709    1.050022
# 0610010K14Rik    1.633539    0.318482    1.338232    1.319906    0.724082
# 0610012G03Rik    1.250494    0.584869    0.656240    1.862847    0.672534
# 0610030E20Rik    1.021152    0.592594    0.937276    1.702173    0.969005
#
#                SRR8835928  SRR8835900  SRR8835904  SRR8835891  SRR8835916  \
# GeneName
# 0610009B22Rik    1.117431    0.731358    1.519465    1.117518    0.669057
# 0610010F05Rik    0.740508    0.682207    0.830300    1.085242    0.866288
# 0610010K14Rik    0.865305    1.264106    0.721409    0.853692    0.831326
# 0610012G03Rik    1.072469    0.937190    1.019688    1.160474    0.888001
# 0610030E20Rik    0.994161    0.797120    1.067343    1.102271    0.818644
#
# ...

# %%
with open("../source/mouse-condition_combined_transposed.csv", encoding="utf-8-sig") as csvfile:
    f = csv.DictReader(csvfile)
    condition_type = [row for row in f]
    print(condition_type)
# Out:
# [{'SRR9601002': '45℃:60min.', 'SRR9601003': '45℃:60min.', 'SRR9601008': '45℃:60min.', 'SRR9601009': '45℃:60min.', 'SRR9601010': '45℃:60min.', 'SRR2068908': '39℃:60min.', 'SRR2068909': '39℃:60min.', 'SRR2068912': '39℃:60min.', 'SRR2068913': '39℃:60min.', 'SRR12044994': '39℃:180min.', 'SRR12044995': '39℃:180min.', 'SRR12044996': '39℃:180min.', 'SRR14119173': '39℃:1440min.', 'SRR14119174': '39℃:1440min.', 'SRR14119175': '39℃:1440min.', 'SRR6
': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR8835930': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR8835892': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR8835896': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR8835903': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR8835912': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR8835914': '42.4℃(from 39.5±0.2°C):No_description.', 'SRR5306699': '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.', 'SRR5306700': '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.', 'SRR5306703': '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.', 'SRR5306704': '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.', 'SRR5306707': '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.', 'SRR5306708': '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.', 'SRR8485461': '43℃:30min.', 'SRR8485462': '43℃:30min.', 'SRR8485463': '43℃:31min.', 'SRR8485464': '43℃:31min.', 'SRR8485465': '43℃:32min.', 'SRR8485466': '43℃:32min.', 'SRR8437830': '43℃:33min.', 'SRR8437831': '43℃:33min.', 'SRR8437832': '43℃:34min.', 'SRR8437833': '43℃:34min.', 'SRR8437834': '43℃:35min.', 'SRR8437835': '43℃:35min.', 'SRR13571059': '43℃:25min.', 'SRR13571060': '43℃:25min.', 'SRR13571061': '43℃:25min.', 'SRR13571065': '43℃:25min.', 'SRR13571066': '43℃:25min.', 'SRR13571067': '43℃:25min.', 'SRR11684187': '42℃:20min.', 'SRR11684188': '42℃:20min.', 'SRR11684189': '42℃:20min.', 'SRR11684190': '42℃:20min.', 'SRR11684182': '42℃:20min.', 'SRR11684183': '42℃:20min.', 'SRR11684184': '42℃:20min.', 'SRR11684185': '42℃:20min.', 'SRR11684186': '42℃:20min.', 'SRR7463322': '43℃:30min.', 'SRR7463323': '43℃:30min.', 'SRR7463324': '43℃:30min.', 'SRR7463325': '43℃:30min.'}

# %%
df1.rename(mapper=condition, axis=1, inplace= True)
df1
# Out:
#                42.4℃(from 39.5±0.2°C):No_description.  \
# GeneName
# 0610009B22Rik                                0.888477
# 0610010F05Rik                                1.301893
# 0610010K14Rik                                1.633539
# 0610012G03Rik                                1.250494
# 0610030E20Rik                                1.021152
# ...                                               ...
# Zyg11a                                       1.000000
# Zyg11b                                       0.994437
# Zyx                                          1.275867
# Zzef1                                        1.191587
# Zzz3                                         0.873637
#
#                42.4℃(from 39.5±0.2°C):No_description.  \
# GeneName
# 0610009B22Rik                                0.472901
# 0610010F05Rik                                0.993249
# 0610010K14Rik                                0.318482
# 0610012G03Rik                                0.584869
# ...

# %%
sample_list = df1.columns.unique()
column_types = {col: [] for col in sample_list}
print(column_types)
# Out:
# {'42.4℃(from 39.5±0.2°C):No_description.': [], '39℃:60min.': [], '42℃:30min.': [], '38℃:120min/day_3days': [], '42℃:60min.': [], '43℃:45min.': [], '42℃:45min.': [], '42℃:135min.': [], '38℃:720min.': [], '35 ± 1°C:6d.': [], '39℃:1440min.': [], '42℃:20min.': [], '43℃:25min.': [], '45℃:60min.': [], '39℃:180min.': [], '43℃:30min.': [], '36℃:120min./day_13days.': [], '44℃:120min.': [], '41.5\u2009°C\u2009±\u20090.2\u2009°C:15min.': [], '42℃:480min.': [], '39.5℃:3d.': [], '43℃:31min.': [], '43℃:32min.': [], '43℃:33min.': [], '43℃:34min.': [], '43℃:35min.': [], '44℃_48℃:120min._480min.': [], '42℃:25min.': [], '42℃:40min.': [], '42℃:12min.': [], '42℃:2.5min.': [], '45℃:15min.': []}

# %%
temp = pd.DataFrame()

# Extract unique column name 
sample_list = df1.columns.unique()

for col in sample_list:  # distinct UP, DOWN, ALL from df1
    thre = df1.filter(like = col)>=5 
    temp[col + '-up' ] = thre.sum(axis=1)
    thre = df1.filter(like = col)<=1/5
    temp[col + '-down' ] = thre.sum(axis=1)
    thre = df1.filter(like = col) >= 0
    temp[col  + '-all'] = thre.sum(axis=1)

all_columns = temp.filter(regex='-all$')  #ALL pair (for check)
temp["all(check)"] = all_columns.sum(axis=1)

thre =df1>= 0  # ALL pair
temp["all"] = thre.sum(axis=1)

for word in sample_list:
    temp["unchange_" + word] = temp[word + "-all"] - temp[word + "-up"] - temp[word + "-down"] # unchnage
    temp["HN5_" + word] =  temp[word + "-up"] - temp[word + "-down"] #HN-score (threshold 5)


total_columns = temp.filter(regex='^HN5')  #Total_HN-score
temp["Total_HN-score"] = total_columns.sum(axis=1)

temp
# Out:
#                42.4℃(from 39.5±0.2°C):No_description.-up  \
# GeneName
# 0610009B22Rik                                          2
# 0610010F05Rik                                          2
# 0610010K14Rik                                          2
# 0610012G03Rik                                          2
# 0610030E20Rik                                          2
# ...                                                  ...
# Zyg11a                                                 0
# Zyg11b                                                 2
# Zyx                                                    2
# Zzef1                                                  2
# Zzz3                                                   2
#
#                42.4℃(from 39.5±0.2°C):No_description.-down  \
# GeneName
# 0610009B22Rik                                            0
# 0610010F05Rik                                            0
# 0610010K14Rik                                            0
# ...

# %%
tempHN5= temp.sort_values(by= "Total_HN-score", ascending=False)
tempHN5
# Out:
#                42.4℃(from 39.5±0.2°C):No_description.-up  \
# GeneName
# Hspa1b                                                14
# Hspa1a                                                15
# Hspb1                                                 18
# Gm20481                                               16
# Atf3                                                  16
# ...                                                  ...
# Il4i1                                                  0
# Tmem89                                                 0
# Spata45                                                0
# Fam24b                                                 0
# 1700028K03Rik                                          0
#
#                42.4℃(from 39.5±0.2°C):No_description.-down  \
# GeneName
# Hspa1b                                                   0
# Hspa1a                                                   0
# Hspb1                                                    0
# ...

# %%
tempHN5.to_csv('../source/HN-score_mouse' + '_HN5' + '_condition_all.csv', sep=",")
