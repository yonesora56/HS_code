# %% [markdown]
# ### Sequencing method type specific HN-score calculation method

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %matplotlib inline

plt.style.use('ggplot')

# %% [markdown]
# ### Using the HN-ratio table

# %%
df = pd.read_csv("../source/HN-ratio_human_All.csv", sep=",")
df.head()
# Out:
#   GeneName  SRR8392699  SRR8392700  SRR8392703  SRR8392704  SRR10129832  \
# 0     A1BG    0.937577    0.905060    1.173431    0.951361     1.616084
# 1     A1CF    1.274827    1.000000    1.000000    1.000000     1.578923
# 2      A2M    0.954195    1.510970    1.340899    0.800410     2.867888
# 3    A2ML1    1.078959    0.649897    0.789869    1.665942     2.674006
# 4  A3GALT2    1.000000    1.000000    1.000000    1.000000     0.924578
#
#    SRR9029562  SRR9029564  SRR9029566  SRR3309259  ...  SRR9257642  \
# 0    1.587653    0.839417    0.707164    0.688915  ...    0.150518
# 1    1.121376    1.125679    1.256608    0.867105  ...    1.000000
# 2    0.271588    1.027820    0.628021    0.646622  ...    1.000000
# 3    8.028230    3.515341    9.282938    0.929338  ...    1.000000
# 4    1.000000    1.000000    0.468382    0.600246  ...    1.000000
#
#    SRR9257643  SRR9257644  SRR9257645  SRR12801712  SRR12801713  SRR12801714  \
# ...

# %%
# set index 
df1=df.set_index('GeneName')
df1.head()
# Out:
#           SRR8392699  SRR8392700  SRR8392703  SRR8392704  SRR10129832  \
# GeneName
# A1BG        0.937577    0.905060    1.173431    0.951361     1.616084
# A1CF        1.274827    1.000000    1.000000    1.000000     1.578923
# A2M         0.954195    1.510970    1.340899    0.800410     2.867888
# A2ML1       1.078959    0.649897    0.789869    1.665942     2.674006
# A3GALT2     1.000000    1.000000    1.000000    1.000000     0.924578
#
#           SRR9029562  SRR9029564  SRR9029566  SRR3309259  SRR3309260  ...  \
# GeneName                                                              ...
# A1BG        1.587653    0.839417    0.707164    0.688915    0.807707  ...
# A1CF        1.121376    1.125679    1.256608    0.867105    0.542718  ...
# A2M         0.271588    1.027820    0.628021    0.646622    1.000000  ...
# A2ML1       8.028230    3.515341    9.282938    0.929338    0.266727  ...
# A3GALT2     1.000000    1.000000    0.468382    0.600246    0.241123  ...
#
# ...

# %% [markdown]
# ### Store SRR number data and sample data as a dictionary data type

# %%
with open("../source/human-sequencing-method.csv", encoding="utf-8-sig") as csvfile:   # create coresponding CSV file 
    f = csv.DictReader(csvfile)
    sequencing_type = [row for row in f]
    print(sequencing_type)
# Out:
# [{'SRR8392699': 'RNA-seq', 'SRR8392700': 'RNA-seq', 'SRR8392703': 'RNA-seq', 'SRR8392704': 'RNA-seq', 'SRR8392707': 'Ribo-seq', 'SRR8392708': 'Ribo-seq', 'SRR8392711': 'Ribo-seq', 'SRR8392712': 'Ribo-seq', 'SRR2522096': 'RNA-seq', 'SRR2522099': 'RNA-seq', 'SRR2522102': 'RNA-seq', 'SRR10129832': 'RNA-seq', 'SRR13436541': 'RNA-seq', 'SRR13436542': 'RNA-seq', 'SRR13436543': 'RNA-seq', 'SRR7309387': 'RNA-seq', 'SRR9029562': 'RNA-seq', 'SRR9029564': 'RNA-seq', 'SRR9029566': 'RNA-seq', 'SRR9029563': 'MeRIP-
#            RNA-seq   RNA-seq   RNA-seq   RNA-seq   RNA-seq   RNA-seq  \
# GeneName
# A1BG      0.937577  0.905060  1.173431  0.951361  1.616084  1.587653
# A1CF      1.274827  1.000000  1.000000  1.000000  1.578923  1.121376
# A2M       0.954195  1.510970  1.340899  0.800410  2.867888  0.271588
# A2ML1     1.078959  0.649897  0.789869  1.665942  2.674006  8.028230
# A3GALT2   1.000000  1.000000  1.000000  1.000000  0.924578  1.000000
# ...            ...       ...       ...       ...       ...       ...
# ZYG11A    0.760432  0.909720  0.482176  0.646283  1.120735  2.408908
# ZYG11B    0.787264  0.721801  1.000042  0.542887  1.157050  1.273877
# ZYX       0.801273  0.900931  1.045951  1.061333  1.631890  1.232130
# ZZEF1     0.919589  1.146141  2.152184  1.007932  2.294421  1.007538
# ZZZ3      1.047701  1.043861  1.133138  0.843305  1.712004  1.156953
#
#            RNA-seq   RNA-seq   RNA-seq   RNA-seq  ...   RNA-seq    RNA-seq  \
# ...

# %%
# Only 5 or 1/5 threshold (HN5)

temp = pd.DataFrame()

# Extract unique column name 
sample_list = df1.columns.unique()

for col in sample_list:  # distinct UP, DOWN, ALL from df1
    thre = df1.filter(like = col)>=5 
    temp[col + '-up' ] = thre.sum(axis=1)
    thre = df1.filter(like = col)<=1/5
    temp[col + '-down' ] = thre.sum(axis=1)
    thre = df1.filter(like = col) >= 0
    temp[col  + '-all'] = thre.sum(axis=1)

all_columns = temp.filter(regex='-all$')  #ALL pair (for check)
temp["all(check)"] = all_columns.sum(axis=1)

thre =df1>= 0  # ALL pair
temp["all"] = thre.sum(axis=1)

for word in sample_list:
    temp["unchange_" + word] = temp[word + "-all"] - temp[word + "-up"] - temp[word + "-down"] # unchnage
    temp["HN5_" + word] =  temp[word + "-up"] - temp[word + "-down"] #HN-score (threshold 5)


total_columns = temp.filter(regex='^HN5')  #Total_HN-score
temp["Total_HN-score"] = total_columns.sum(axis=1)

temp
# Out:
#           RNA-seq-up  RNA-seq-down  RNA-seq-all  SLAM-seq-up  SLAM-seq-down  \
# GeneName
# A1BG               5             3          192            0              0
# A1CF               3             1          192            0              0
# A2M                7             6          192            0              0
# A2ML1              6             1          192            0              0
# A3GALT2            8             5          192            0              0
# ...              ...           ...          ...          ...            ...
# ZYG11A             4             1          192            0              0
# ZYG11B             4             3          192            0              0
# ZYX                8             5          192            0              0
# ZZEF1              6             1          192            0              0
# ZZZ3               6             0          192            0              0
#
# ...

# %%
tempHN5= temp.sort_values(by= "Total_HN-score", ascending=False)
tempHN5
# Out:
#           RNA-seq-up  RNA-seq-down  RNA-seq-all  SLAM-seq-up  SLAM-seq-down  \
# GeneName
# HSPA6            156             1          192            2              0
# HSPA1A           146             0          192            0              0
# HSPA1B           147             0          192            0              0
# DNAJB1           135             1          192            0              0
# BAG3             112             1          192            1              0
# ...              ...           ...          ...          ...            ...
# N4BP1              2            26          192            0              0
# ZNF784             5            26          192            2              1
# TSSK3             13            40          192            2              1
# HRCT1              2            27          192            0              3
# H1-3              10            24          192            0              0
#
# ...

# %%
tempHN5.to_csv('../source/HN-score_human' + '_HN5' + '_sequencing_all.csv', sep=",")
