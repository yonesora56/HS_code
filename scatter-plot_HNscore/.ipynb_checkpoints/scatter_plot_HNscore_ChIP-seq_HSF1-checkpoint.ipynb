# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import pandas as pd
import numpy as np

rcParams["font.family"]     = "Arial"
rcParams["font.sans-serif"] = "Hiragino Maru Gothic Pro"
plt.style.use("ggplot")

# %%
data = pd.read_csv("./HN-score_HN5_convert.csv")
data1 = pd.DataFrame(data)
data1
# Out:
#       human symbol mouse symbol  human  mouse  Total  HSF1 average peak  \
# 0             A1BG         A1bg      3      1      4           0.000000
# 1             A1CF         A1cf      2      0      2           0.000000
# 2              A2M          A2m      1     -6     -5           0.000000
# 3            A2ML1        A2ml1     11      3     14          25.038835
# 4          A3GALT2      A3galt2      7     14     21           0.000000
# ...            ...          ...    ...    ...    ...                ...
# 16147       ZYG11A       Zyg11a      7     -1      6           1.242718
# 16148       ZYG11B       Zyg11b      1     -2     -1           2.825243
# 16149          ZYX          Zyx      5      4      9          14.242718
# 16150        ZZEF1        Zzef1      6      1      7           7.825243
# 16151         ZZZ3         Zzz3      7     -4      3          11.912621
#
#        HSF2 average peak  PPARGC1A average peak
# 0                    0.0                      0
# 1                    0.0                      0
# 2                    0.0                      0
# 3                    0.0                      0
# 4                    0.0                      0
# ...                  ...                    ...
# 16147                0.0                      0
# 16148                0.0                      0
# 16149                0.0                      0
# 16150                0.0                      0
# 16151                0.0                      0
#
# [16152 rows x 8 columns]

# %%
#  200 ≦ gene2pubmed data 

# HSPA1B,  HSPA1A, DNAJB1, BAG3, HSPH1, HSPB1, FOS, CRYAB, HSPA1L, ATF3
#SERPINH1, EGR1, CLU, HSP90AA1, DNAJA1, JUN, ACTA1, ADORA2A, HSPD1, UBC
#SELPLG, SOCS3,  HSPA8, BST2, CXCR4, 


data2 = {
    "X": [380, 376,281,232,231,223,216,190,182,173, 
138,131,108, 105, 93, 91, 75, 74, 67, 67, 
65, 64, 58, 45, 43],
    "Y": [378.029126, 246.796117, 507.893204, 219.242718, 685.116505, 328.699029, 84.893204, 50.84466, 246.796117, 19.466019,
         297.330097, 3.407767, 183.116505,  849.126214, 476.728155, 112.368932, 0, 0, 1151.048544, 205.281553,
         1.262136, 5.242718, 524.475728, 69.728155, 0]
}

# %%
# 50 ≦ gene2pubmed < 200

#DNAJB4, HSPB8, EGR2, FOSB, HSPA4L, NR4A3, CLDN6, DDIT4, FERMT3, PPP1R15A
#OXT,  GADD45G, HEY1, HSPE1, CD79A, CARD9, H3C8, FGF18, GADD45B, 

data3 = {
    "X": [169, 136,132,131,109,87, 79, 72, 68, 68, 
          67, 64, 61, 61,58, 51, 47, 46,46 ],
    "Y": [79.815534, 39.679612, 15.990291, 24.320388, 187.349515, 20.330097, 3.669903, 39.349515, 0, 23.339806,
         0, 0, 24.242718, 1151.048544, 0, 0,  4.252427, 0,  19.145631]
}

# %%
# gene2pubmed < 50

#ZFAND2A, RRAD, DEDD2, DNAJA4, TENT5A, TEX43, LY6G6C, XIRP1, USPL1, ARC
#BEST2, PLA2G12B, LRIT3, NOXRED1, RASL11A, SLC5A3, CHAC1, ARL9, CCDC194, TMC4
#PRR18, ABHD3, LMAN1L, IQCF1, MYOCOS, IQCA1L, RRH, PDE6G, GUCA1B, PIP5KL1
#NRN1L, TEX29

data4 = {
    "X": [177,173,165,141, 137,135,115,100,99, 94, 
        78, 75, 74, 72, 72, 69, 63, 62, 62, 62, 
         61, 57, 57, 55, 53, 52, 51, 46, 44,  42,
         41, 40],
    "Y": [383.621359 , 
          42.524272, 
          198.970874, 
          143.194175, 
          67.009709, 
          0, 
          1.834951, 
          1.718447, 
          808.38835,
          2.883495,
         0, 0, 0, 0, 0.893204, 355.009709, 2.932039, 0, 0, 0,
         0, 348.514563, 31.029126, 0, 0, 0, 0, 42.359223, 0, 1.572816, 
         0, 2.368932]
}

# %%
ax = plt.axes()
ax.set_facecolor('white')
plt.scatter(
            data1["Total"],   
            data1["HSF1 average peak"],    
            marker = "o",     
            s = 5,            
            c = "gray",     
            edgecolor = "black",   
            linewidth = 0.01, 
            alpha = 0.5,     
            label = "all"  
            )

plt.scatter(
            data2["X"],          
            data2["Y"],       
            s = 10,        
            c = "red",         
            edgecolor = "white",    
            linewidth = 1,      
            alpha = 1,      
            )

plt.scatter(
            data3["X"],      
            data3["Y"],    
            s = 15,        
            c = "red",      
            edgecolor = "black",   
            linewidth = 0.2,   
            alpha = 1,     
            )

plt.scatter(
            data4["X"],     
            data4["Y"],     
            marker = "D" , 
            s = 20,          
            c = "orange",     
            edgecolor = "black",    
            linewidth = 0.1,      
            alpha = 1,      
            )

plt.grid(color='b', linestyle=':', linewidth=0.1)
ax.set_xlim(-100, 400)
ax.set_ylim(-40, 1200)
ax.minorticks_on()
plt.grid(which = "both", axis="x")
plt.rcParams["figure.figsize"] = [14, 6]  
plt.xlabel("Total HN-score", fontsize=10) 
plt.ylabel("ChIP-seq HSF1", fontsize=10)
plt.tick_params(labelsize=9)
plt.savefig("./image/HSF1_average_peak.png", format="png", dpi=500)
