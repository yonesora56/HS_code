# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

plt.style.use('ggplot')

# %%
df = pd.read_csv("./source/HS_treatment.csv", sep=",")
df.head()
# Out:
#   Treatment time  Human  Mouse
# 0        2.5min.      0      6
# 1         12min.      0      8
# 2         15min.      6      8
# 3         20min.      0     15
# 4         25min.      0     10

# %%
df2 = df.set_index('Treatment time')
df2.head()
# Out:
#                 Human  Mouse
# Treatment time
# 2.5min.             0      6
# 12min.              0      8
# 15min.              6      8
# 20min.              0     15
# 25min.              0     10

# %%
sns.set_palette("bright")
 
plt.rcParams["figure.figsize"] = [15,6]   
df2.plot(kind = 'bar' )
plt.grid(which = "both", axis="x")
plt.xticks(fontsize=40, rotation=45)
plt.xlabel('Treatment time ', size = 20)
plt.ylabel('pair ', size = 15)
plt.legend(fontsize=20, ncol=1)
plt.tick_params(labelsize=12)
plt.ylim(0, 140)
plt.show
plt.savefig("./files/HS_treatment.png", format="png", dpi=300)
