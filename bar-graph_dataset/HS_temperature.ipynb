# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

plt.style.use('ggplot')

# %%
df = pd.read_csv("./source/HS_temperature.csv", sep=",")
df.head()
# Out:
#   temprerature  Human  Mouse
# 0           35      0      9
# 1           36      0     23
# 2           38      0      5
# 3           39     17     10
# 4         39.5      0      2

# %%
df2 = df.set_index('temprerature')
df2.head()
# Out:
#               Human  Mouse
# temprerature
# 35                0      9
# 36                0     23
# 38                0      5
# 39               17     10
# 39.5              0      2

# %%
sns.set_palette("bright")
 
plt.rcParams["figure.figsize"] = [15,6]   
df2.plot(kind = 'bar' )
plt.grid(which = "both", axis="x")
plt.xticks(fontsize=20, rotation=45)
plt.xlabel('temperature (degree, ℃) ', size = 20)
plt.ylabel('pair ', size = 15)
plt.legend(fontsize=20, ncol=1)
plt.tick_params(labelsize=15)
plt.ylim(0, 200)
plt.show
plt.savefig("./files/HS_temperature.png", format="png", dpi=300)
